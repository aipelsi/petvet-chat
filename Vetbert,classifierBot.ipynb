# %% [markdown]
# <a href="https://colab.research.google.com/github/aipelsi/petvet-chat/blob/main/Vetbert%2CclassifierBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **VetBERT Disease Syndrome Classifier**: https://huggingface.co/havocy28/VetBERTDx

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="havocy28/VetBERTDx")

from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Load the tokenizer and model from the Hugging Face Hub
model_name = 'havocy28/VetBERTDx'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Example text to classify
text = "Hx: 7 yo canine with history of vomiting intermittently since yesterday. No other concerns. Still eating and drinking normally. cPL negative."

# Encode the text and prepare inputs for the model
inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

# Predict and compute softmax to get probabilities
with torch.no_grad():
    logits = model(**inputs).logits
    probabilities = torch.softmax(logits, dim=-1)

# Retrieve label mapping from model's configuration
label_map = model.config.id2label

# Combine labels and probabilities, and sort by probability in descending order
sorted_probs = sorted(((prob.item(), label_map[idx]) for idx, prob in enumerate(probabilities[0])), reverse=True, key=lambda x: x[0])

# Display sorted probabilities and labels
for prob, label in sorted_probs:
    print(f"{label}: {prob:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.71k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Device set to use cpu
# enteropathy: 0.9873
# appetite disorder: 0.0023
# upper respiratory tract disorder: 0.0012
# pancreatic disorder: 0.0010
# repeat: 0.0008
# disorder not diagnosed: 0.0005
# unknown: 0.0005
# post operative complication: 0.0005
# fever (undiagnosed): 0.0005
# adverse reaction to drug: 0.0004
# abscess: 0.0004
# lethargy: 0.0004
# blood test: 0.0003
# prophylaxis: 0.0003
# dental disorder: 0.0003
# intoxication: 0.0003
# oral cavity disorder: 0.0003
# blank: 0.0003
# traumatic injury: 0.0002
# claw/nail disorder: 0.0002
# female reproductive disorder: 0.0002
# lower respiratory tract disorder: 0.0002
# liver disorder: 0.0002
# heart disorder: 0.0002
# musculoskeletal disorder: 0.0002
# palliative: 0.0001
# endocrine system disorder: 0.0001
# ophthalmological disorder: 0.0001
# urinary tract disorder: 0.0001
# male reproductive disorder: 0.0001
# other species: 0.0001
# neoplasia: 0.0001
# lymph node disorder: 0.0001
# skin disorder: 0.0001
# foreign body: 0.0001
# kidney disorder: 0.0001
# ear disorder: 0.0000
# mass: 0.0000
# neurological disorder: 0.0000
